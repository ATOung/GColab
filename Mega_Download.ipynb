# %% [markdown]
# ##MEGA Tool 1

# %%
# !apt-get -y update > null
# !apt-get install megatools > null

Folder_Patch = "/content/drive/Shareddrives/Main/Lastest/One Piece" #@param {type:"string"}
# %cd "$Folder_Patch"

url_link1 = "https://mega.nz/folder/Zs8l3YLA#6VP1RBWaInFeBFOzePKpbQ" #@param {type:"string"}
# !megadl "$url_link1"
print(" successfully!")
# Out:
# /content/drive/Shareddrives/Main/Lastest/One Piece
# ERROR: File already exists at /content/drive/Shareddrives/Main/Lastest/One Piece/45 Neo Channel One Piece FHD  (1080p )    MM SUB            Arc Arlong.mp4
# ERROR: File already exists at /content/drive/Shareddrives/Main/Lastest/One Piece/44 Neo Channel One Piece FHD  (1080p )    MM SUB         Arc Arlong.mp4
# ERROR: File already exists at /content/drive/Shareddrives/Main/Lastest/One Piece/43 Neo Channel One Piece FHD  (1080p )    MM SUB         Arc Arlong.mp4
# ERROR: File already exists at /content/drive/Shareddrives/Main/Lastest/One Piece/42 Neo Channel One Piece FHD  (1080p )    MM SUB      Arc Arlong.mp4
# ERROR: File already exists at /content/drive/Shareddrives/Main/Lastest/One Piece/41 Neo Channel One Piece FHD  (1080p )    MM SUB       Arc Arlong.mp4
# ERROR: File already exists at /content/drive/Shareddrives/Main/Lastest/One Piece/39 Neo Channel One Piece FHD  (1080p )    MM SUB      Arc Arlong.mp4
# ERROR: File already exists at /content/drive/Shareddrives/Main/Lastest/One Piece/40 Neo Channel One Piece FHD  (1080p )    MM SUB             Arc Arlong.mp4
# ERROR: File already exists at /content/drive/Shareddrives/Main/Lastest/One Piece/51  Neo Channel One Piece FHD  (1080p )    MM SUB    Arc Loguetown.mp4
# ERROR: File already exists at /content/drive/Shareddrives/Main/Lastest/One Piece/52  Neo Channel One Piece FHD  (1080p )    MM SUB          Arc Loguetown.mp4
# ERROR: File already exists at /content/drive/Shareddrives/Main/Lastest/One Piece/53   Neo Channel One Piece FHD  (1080p )    MM SUB          Arc Loguetown.mp4
# ERROR: File already exists at /content/drive/Shareddrives/Main/Lastest/One Piece/54   Neo Channel One Piece FHD  (1080p )    MM SUB      Arc Île du Navire de Guerre.mp4
# ERROR: File already exists at /content/drive/Shareddrives/Main/Lastest/One Piece/55    Neo Channel One Piece FHD  (1080p )    MM SUB      Arc Île du Navire de Guerre.mp4
# ERROR: File already exists at /content/drive/Shareddrives/Main/Lastest/One Piece/56  Neo Channel One Piece FHD  (1080p )    MM SUB   Arc Île du Navire de Guerre.mp4
# ERROR: File already exists at /content/drive/Shareddrives/Main/Lastest/One Piece/57   Neo Channel One Piece FHD  (1080p )    MM SUB     Arc Île du Navire de Guerre.mp4
# ERROR: File already exists at /content/drive/Shareddrives/Main/Lastest/One Piece/58     Neo Channel One Piece FHD  (1080p )    MM SUB      Arc Île du Navire de Guerre.mp4
# ERROR: File already exists at /content/drive/Shareddrives/Main/Lastest/One Piece/59  Neo Channel One Piece FHD  (1080p )    MM SUB    Arc Île du Navire de Guerre.mp4
# F /content/drive/Shareddrives/Main/Lastest/One Piece/60   Neo Channel One Piece FHD  (1080p )    MM SUB      Arc Île du Navire de Guerre.mp4
# F /content/drive/Shareddrives/Main/Lastest/One Piece/61   Neo Channel One Piece FHD  (1080p )    MM SUB      Arc Île du Navire de Guerre.mp4
# F /content/drive/Shareddrives/Main/Lastest/One Piece/62   Neo Channel One Piece FHD  (1080p )    MM SUB       Arc Laboon.mp4
# F /content/drive/Shareddrives/Main/Lastest/One Piece/63  Neo Channel One Piece FHD  (1080p )    MM SUB    Arc Laboon.mp4
# F /content/drive/Shareddrives/Main/Lastest/One Piece/64    Neo Channel One Piece FHD  (1080p )    MM SUB    Arc Whiskey Peak.mp4
# F /content/drive/Shareddrives/Main/Lastest/One Piece/65 Neo Channel One Piece FHD  (1080p )    MM SUB     Arc Whiskey Peak.mp4
# F /content/drive/Shareddrives/Main/Lastest/One Piece/66   Neo Channel One Piece FHD  (1080p )    MM SUB  Arc Whiskey Peak.mp4
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 2 seconds
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 4 seconds
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 8 seconds
# ERROR: Download failed for /39- 70  One Piece Neo Channel/66   Neo Channel One Piece FHD  (1080p )    MM SUB  Arc Whiskey Peak.mp4: Data download failed: Server returned 509 (over quota)
# F /content/drive/Shareddrives/Main/Lastest/One Piece/67    Neo Channel One Piece FHD  (1080p )    MM SUB  Arc Whiskey Peak.mp4
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 2 seconds
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 4 seconds
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 8 seconds
# ERROR: Download failed for /39- 70  One Piece Neo Channel/67    Neo Channel One Piece FHD  (1080p )    MM SUB  Arc Whiskey Peak.mp4: Data download failed: Server returned 509 (over quota)
# F /content/drive/Shareddrives/Main/Lastest/One Piece/68   Neo Channel One Piece FHD  (1080p )    MM SUB    Arc Whiskey Peak.mp4
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 2 seconds
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 4 seconds
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 8 seconds
# ERROR: Download failed for /39- 70  One Piece Neo Channel/68   Neo Channel One Piece FHD  (1080p )    MM SUB    Arc Whiskey Peak.mp4: Data download failed: Server returned 509 (over quota)
# F /content/drive/Shareddrives/Main/Lastest/One Piece/69    Neo Channel One Piece FHD  (1080p )    MM SUB   Arc Whiskey Peak.mp4
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 2 seconds
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 4 seconds
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 8 seconds
# ERROR: Download failed for /39- 70  One Piece Neo Channel/69    Neo Channel One Piece FHD  (1080p )    MM SUB   Arc Whiskey Peak.mp4: Data download failed: Server returned 509 (over quota)
# F /content/drive/Shareddrives/Main/Lastest/One Piece/70    Neo Channel One Piece FHD  (1080p )    MM SUB       Arc Little Garden.mp4
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 2 seconds
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 4 seconds
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 8 seconds
# ERROR: Download failed for /39- 70  One Piece Neo Channel/70    Neo Channel One Piece FHD  (1080p )    MM SUB       Arc Little Garden.mp4: Data download failed: Server returned 509 (over quota)
# F /content/drive/Shareddrives/Main/Lastest/One Piece/46 Neo Channel One Piece FHD  (1080p )    MM SUB Aventures de la Bande à Baggy.mp4
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 2 seconds
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 4 seconds
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 8 seconds
# ERROR: Download failed for /39- 70  One Piece Neo Channel/46 Neo Channel One Piece FHD  (1080p )    MM SUB Aventures de la Bande à Baggy.mp4: Data download failed: Server returned 509 (over quota)
# F /content/drive/Shareddrives/Main/Lastest/One Piece/47  Neo Channel One Piece FHD  (1080p )    MM SUB      arc  Les Aventures de la Bande à Baggy.mp4
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 2 seconds
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 4 seconds
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 8 seconds
# ERROR: Download failed for /39- 70  One Piece Neo Channel/47  Neo Channel One Piece FHD  (1080p )    MM SUB      arc  Les Aventures de la Bande à Baggy.mp4: Data download failed: Server returned 509 (over quota)
# F /content/drive/Shareddrives/Main/Lastest/One Piece/48   Neo Channel One Piece FHD  (1080p )    MM SUB    Arc Loguetown.mp4
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 2 seconds
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 4 seconds
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 8 seconds
# ERROR: Download failed for /39- 70  One Piece Neo Channel/48   Neo Channel One Piece FHD  (1080p )    MM SUB    Arc Loguetown.mp4: Data download failed: Server returned 509 (over quota)
# F /content/drive/Shareddrives/Main/Lastest/One Piece/49  Neo Channel One Piece FHD  (1080p )    MM SUB       Arc Loguetown.mp4
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 2 seconds
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 4 seconds
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 8 seconds
# ERROR: Download failed for /39- 70  One Piece Neo Channel/49  Neo Channel One Piece FHD  (1080p )    MM SUB       Arc Loguetown.mp4: Data download failed: Server returned 509 (over quota)
# F /content/drive/Shareddrives/Main/Lastest/One Piece/50      Neo Channel One Piece FHD  (1080p )    MM SUB        Arc Loguetown.mp4
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 2 seconds
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 4 seconds
# WARNING: chunk download failed (Server returned 509 (over quota)), re-trying after 8 seconds
# ERROR: Download failed for /39- 70  One Piece Neo Channel/50      Neo Channel One Piece FHD  (1080p )    MM SUB        Arc Loguetown.mp4: Data download failed: Server returned 509 (over quota)
#  successfully!

# %% [markdown]
# ##MEGA Tool 2

# %%
# @markdown <center><h3>Input Your Mega ID</h3></center><br>
from functools import wraps
import errno
import os
import signal
import subprocess
import shlex


class TimeoutError(Exception):
    pass


def timeout(seconds=10, error_message=os.strerror(errno.ETIME)):
    def decorator(func):
        def _handle_timeout(signum, frame):
            raise TimeoutError(error_message)

        def wrapper(*args, **kwargs):
            signal.signal(signal.SIGALRM, _handle_timeout)
            signal.alarm(seconds)
            try:
                result = func(*args, **kwargs)
            finally:
                signal.alarm(0)
            return result

        return wraps(func)(wrapper)

    return decorator


if not os.path.exists("/root/.ipython/ocr.py"):
    from subprocess import run
    from shlex import split

    shellCmd = "wget -qq https://raw.githubusercontent.com/biplobsd/OneClickRun/master/res/ocr.py \
                    -O /root/.ipython/ocr.py"
    run(split(shellCmd))
from ocr import runSh

@timeout(10)
def runShT(args):
    return runSh(args, output=True)


# MEGAcmd installing
if not os.path.exists("/usr/bin/mega-cmd"):
    print("Installing MEGA ...")
    runSh('sudo apt-get -y update')
    runSh('sudo apt-get -y install libmms0 libc-ares2 libc6 libcrypto++6 libgcc1 libmediainfo0v5 libpcre3 libpcrecpp0v5 libssl1.1 libstdc++6 libzen0v5 zlib1g apt-transport-https')
    runSh('sudo curl -sL -o /var/cache/apt/archives/MEGAcmd.deb https://mega.nz/linux/MEGAsync/Debian_9.0/amd64/megacmd-Debian_9.0_amd64.deb', output=True)
    runSh('sudo dpkg -i /var/cache/apt/archives/MEGAcmd.deb', output=True)
    print("MEGA is installed.")
else:
    # !pkill mega-cmd

# INPUT YOUR MEGA ID

USERNAME = "atoung286@gmail.com"  # @param {type:"string"}
PASSWORD = "HACKer286*#"  # @param {type:"string"}
if not (USERNAME == "" or PASSWORD == ""):
    try:
        runShT(f"mega-login {USERNAME} {PASSWORD}")
    except TimeoutError:
        runSh('mega-whoami', output=True)
else:
    print("Please Input your Mega IDs.")
# @markdown *After signing in, use the above cell(Main Cell) to transfer files from Mega to GDrive using the transfer quota of your Mega Pro Account*

# %%
import sys, os, urllib.request
import time
import subprocess
import contextlib
from IPython.display import clear_output
#@markdown <br><center><img src='https://mega.nz/favicon.ico?v=3' height="50" alt="MEGA-logo"/></center>
#@markdown <center><h2>Transfer from Mega to GDrive</h2></center><br>
HOME = os.path.expanduser("~")
if not os.path.exists(f"{HOME}/.ipython/ocr.py"):
    hCode = "https://raw.githubusercontent.com/biplobsd/" \
                "OneClickRun/master/res/ocr.py"
    urllib.request.urlretrieve(hCode, f"{HOME}/.ipython/ocr.py")

from ocr import (
    runSh,
    loadingAn,
)
#@title MEGA public link download
URL = "https://mega.nz/folder/IsdnkaZa#Vjzc9yZF6HIsTm9NiQIXvQ" #@param {type:"string"}
OUTPUT_PATH = "" #@param {type:"string"}
#@markdown #####_*Sometimes this cell doesn't stop itself after the completion of the transfer. In case of that stop the cell manually._
if not OUTPUT_PATH:
  os.makedirs("downloads", exist_ok=True)
  OUTPUT_PATH = "downloads"
# MEGAcmd installing
if not os.path.exists("/usr/bin/mega-cmd"):
    loadingAn()
    print("Installing MEGA ...")
    runSh('sudo apt-get -y update')
    runSh('sudo apt-get -y install libmms0 libc-ares2 libc6 libcrypto++6 libgcc1 libmediainfo0v5 libpcre3 libpcrecpp0v5 libssl1.1 libstdc++6 libzen0v5 zlib1g apt-transport-https')
    runSh('sudo curl -sL -o /var/cache/apt/archives/MEGAcmd.deb https://mega.nz/linux/MEGAsync/Debian_9.0/amd64/megacmd-Debian_9.0_amd64.deb', output=True)
    runSh('sudo dpkg -i /var/cache/apt/archives/MEGAcmd.deb', output=True)
    print("MEGA is installed.")
    clear_output()

# Unix, Windows and old Macintosh end-of-line
newlines = ['\n', '\r\n', '\r']

def unbuffered(proc, stream='stdout'):
    stream = getattr(proc, stream)
    with contextlib.closing(stream):
        while True:
            out = []
            last = stream.read(1)
            # Don't loop forever
            if last == '' and proc.poll() is not None:
                break
            while last not in newlines:
                # Don't loop forever
                if last == '' and proc.poll() is not None:
                    break
                out.append(last)
                last = stream.read(1)
            out = ''.join(out)
            yield out


def transfare():
    import codecs
    decoder = codecs.getincrementaldecoder("UTF-8")()
    cmd = ["mega-get", URL, OUTPUT_PATH]
    proc = subprocess.Popen(
        cmd,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        # Make all end-of-lines '\n'
        universal_newlines=True,
    )
    for line in unbuffered(proc):
        print(line)



transfare()

# %% [markdown]
# ##Terminal

# %%
ls
